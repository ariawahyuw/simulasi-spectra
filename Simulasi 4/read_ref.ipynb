# %%
from pyspectra.readers.read_spc import read_spc_dir
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
df_spc, dict_spc = read_spc_dir('./Data Referensi/')
df_spc = df_spc.T
# Out:
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)
# x-y(1)

# %%
# Invert index desc
df_spc = df_spc.iloc[::-1]

# %%
df_spc.head()
# Out:
#              acetoacetate.spc  acetylcoenzymeA.spc  acetylglucosamine.spc  \
# 1802.333130          2.025396             4.718572               0.512343
# 1800.652954          2.037963             4.745312               0.712325
# 1798.972778          1.969724             4.767581               0.573100
# 1797.292480          1.970049             4.790565               0.491842
# 1795.612305          2.066077             5.162227               0.484638
#
#              adenine.spc  alanine.spc  amylopectin.spc  amylose.spc  \
# 1802.333130     2.377923     1.294187         0.313112     4.522676
# 1800.652954     2.373374     1.307926         0.327856     4.356924
# 1798.972778     2.438870     1.301665         0.315185     4.491654
# 1797.292480     2.476112     1.332704         0.405403     4.558607
# 1795.612305     2.518394     1.328539         0.350904     4.569659
#
#              arabinose.spc  arginine.spc  ascorbicacid.spc  ...  thymine.spc  \
# ...

# %%
df_spc.tail(5)
# Out:
#             acetoacetate.spc  acetylcoenzymeA.spc  acetylglucosamine.spc  \
# 373.811310          9.856384            71.576550               4.222769
# 371.562347         10.320145            73.177460               4.180205
# 369.313416         11.156961            75.241773               4.311210
# 367.064453         12.433111            77.690329               4.914636
# 364.815491         14.328127            80.173983               5.545926
#
#             adenine.spc  alanine.spc  amylopectin.spc  amylose.spc  \
# 373.811310     5.668756     3.877851        44.136397    77.623440
# 371.562347     5.614540     3.687203        45.911700    78.674098
# 369.313416     5.726980     3.513441        46.199339    79.775998
# 367.064453     5.837083     3.355747        48.641024    80.479982
# 364.815491     5.921288     3.223229        50.980114    81.221828
#
#             arabinose.spc  arginine.spc  ascorbicacid.spc  ...  thymine.spc  \
# ...

# %%
wave_length = df_spc.index.values
wave_length_lag = np.roll(wave_length, -1)
wave_length - wave_length_lag
# Out:
# array([ 1.68017578e+00,  1.68017578e+00,  1.68029785e+00,  1.68017578e+00,
#         1.68029785e+00,  1.68017578e+00,  1.68017578e+00,  1.68029785e+00,
#         1.68017578e+00,  1.68017578e+00,  1.68029785e+00,  1.68017578e+00,
#         1.68017578e+00,  1.68029785e+00,  1.68017578e+00,  1.68017578e+00,
#         1.68029785e+00,  1.68017578e+00,  1.68029785e+00,  1.68017578e+00,
#         1.68017578e+00,  1.68029785e+00,  1.68017578e+00,  1.68017578e+00,
#         1.68029785e+00,  1.68017578e+00,  1.68017578e+00,  1.68029785e+00,
#         1.68017578e+00,  1.68017578e+00,  1.68029785e+00,  1.68017578e+00,
#         1.68029785e+00,  1.68017578e+00,  1.68017578e+00,  1.68029785e+00,
#         1.68017578e+00,  1.68017578e+00,  1.68029785e+00,  1.68017578e+00,
#         1.68017578e+00,  1.68029785e+00,  1.68017578e+00,  1.68017578e+00,
#         1.68029785e+00,  1.68017578e+00,  1.68029785e+00,  1.68017578e+00,
# ...

# %%
#df_spc['oleicacid.spc'].plot()
df_spc['palmiticacid_16.spc'].loc[701.6432495117188:].plot()
df_spc['stearicacid.spc'].loc[701.6432495117188:].plot()
df_spc['']
# Out:
# <Axes: >

# %%
df_spc.index[df_spc.index > 700]
# Out:
# Index([ 701.6432495117188,  703.7356567382812,         705.828125,
#         707.9205932617188,  710.0130004882812,  712.1095581054688,
#          714.209716796875,   716.309814453125,  718.4099731445312,
#         720.5100708007812,
#        ...
#         1787.211181640625,  1788.891357421875, 1790.5716552734375,
#        1792.2518310546875, 1793.9320068359375,    1795.6123046875,
#          1797.29248046875, 1798.9727783203125, 1800.6529541015625,
#        1802.3331298828125],
#       dtype='float64', length=584)
